# %% [markdown]
# ### Grayscaling
#
# - Full color(R,G,B)'den grayscale'e dönüştürme işlemidir. (Black & White)
# - Genellikle görüntü işleme süresini azaltmak için yapılır. (RGB'den grayscale'e...)

# %% [markdown]
# ### Convert Image to Grayscale

# %%
from google.colab.patches import cv2_imshow
import cv2

# %%
image = cv2.imread("input.jpg")
# cv2.imshow('Original', image)
cv2_imshow(image)
cv2.waitKey()

# cvtColot (convert -> grayscale için ...)
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# cv2.imshow("Grayscale", gray_image)
cv2_imshow(gray_image)
cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=1280x853>
# <PIL.Image.Image image mode=L size=1280x853>
